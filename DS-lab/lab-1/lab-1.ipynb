# %% [markdown]
# # DROP THE WORLD

# %%
a = 10
b = 10.6
c = "hello"
d = True
e = [1,3,5,4]

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = 20
b = 10
print(a*b)
# Out:
# 200

# %%
a = 10

# %%
a
# Out:
# 10

# %% [markdown]
# # division

# %%
a = 10
b = 2
print(a//b)
# Out:
# 5

# %% [markdown]
# # Modulus

# %%
a = 5
b = 5
print(a%b)
# Out:
# 0

# %% [markdown]
# # Exponent

# %%
a = 10
b = 2
print(a**b)
# Out:
# 100

# %%
x = 25
print(x)
