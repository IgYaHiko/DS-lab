# %%
a = 25
b = 12.5
c = "Python"
d = True

print("a = ", a, "|Type = ", type(a))
print("b = ", b, "|Type = ", type(b))
print("c = ", c, "|Type = ", type(c))
print("d = ", d, "|Type = ", type(d))
# Out:
# a =  25 |Type =  <class 'int'>
# b =  12.5 |Type =  <class 'float'>
# c =  Python |Type =  <class 'str'>
# d =  True |Type =  <class 'bool'>

# %%
number = 42
decimal = 10.8
language = "Data Science"
is_ready = True
subjects = ["Python", "ML", "AI"]

print("number = ", type(number))
print("decimal = ", type(decimal))
print("language = ", type(language))
print("is_ready = ", type(is_ready))
print("subjects = ", type(subjects))
# Out:
# number =  <class 'int'>
# decimal =  <class 'float'>
# language =  <class 'str'>
# is_ready =  <class 'bool'>
# subjects =  <class 'list'>

# %%
a = 20
b = 10

sum = a + b
print("Sum = ", sum)
# Out:
# Sum =  30

# %%
a = 20
b = 10

sub = a-b
print("Difference = ", sub)
# Out:
# Difference =  10

# %%
a = 20
b = 10

mul = a*b
print("Multiplication = ", mul)
# Out:
# Multiplication =  200

# %%
a = 20
b = 10

div = a/b
print("Division = ", div)
# Out:
# Division =  2.0

# %%
a = 25
b = 7

modulus = a%b
print("Modulus = ", modulus)
# Out:
# Modulus =  4

# %%
a = 24
b = 7

floorDiv = a // b
print("floorDiv = ", floorDiv)
# Out:
# floorDiv =  3

# %%
a = 2
b = 3

exponent = a ** b
print("exponent = ", exponent)
# Out:
# exponent =  8

# %%
a = 20
b = 20

is_equal = a==b

# %%
a = 20
b = 10

is_not_equal = a != b

# %%
a = 10
b = 20

is_lessthan = a < b

# %%
a = 30
b = 20

is_greaterthan = a > b

# %%
a = 20
b = 20

is_lessthan_equal = a <= b

# %%
a = 25
b = 20
is_greaterthan_equal = a >= b

# %%
x = 50
print("Value of x = ", x)
# Out:
# Value of x =  50

# %%
x = 10
x += 5

print("Value of x = ", x)
# Out:
# Value of x =  15

# %%
x = 20
x -= 7
print("Value of x = ", x)
# Out:
# Value of x =  13

# %%
x = 5
x *= 4
print("Value of x = ", x)
# Out:
# Value of x =  20

# %%
x = 20
x /= 4
print("Value of x = ", x)
# Out:
# Value of x =  5.0

# %%
x = 17
x %= 5
print("Value of x = ", x)
# Out:
# Value of x =  2

# %%
x = 2
x **= 4
print("Value of x = ", x)
# Out:
# Value of x =  16

# %%
x = 25
x //= 4
print("Value of x = ", x)
# Out:
# Value of x =  6

# %%
a = 10
b = 20

result = a<b and b>15
print("Result = ", result)
# Out:
# Result =  True

# %%
a = 10
b = 20

result = a>b or a<b
print("Result = ", result)
# Out:
# Result =  True

# %%
a = 10
b = 20

result = not(a>b)
print("Result = ", result)
# Out:
# Result =  True

# %%
age = 20
marks = 85

condition_and = age>=18 and marks>=50
condition_or = age<18 or marks>80
condition_not = not(age<18)

print("Condition and = ", condition_and)
print("Condition or = ", condition_or)
print("Condition not = ", condition_not)
# Out:
# Condition and =  True
# Condition or =  True
# Condition not =  True

# %%
a = 10
b = 6

result = a & b
print("Result = ", result)
# Out:
# Result =  2

# %%
a = 10
b = 6

result = a | b
print("Result = ", result)
# Out:
# Result =  14

# %%
a = 10
b = 6

result = a ^ b
print("Result = ", result)
# Out:
# Result =  12

# %%
a = 10

result = ~a
print("Result = ", result)
# Out:
# Result =  -11

# %%
a = 5

result = a<<2
print("Result = ",result)
# Out:
# Result =  20

# %%
a = 20

result = a>>2
print("Result = ",result)
# Out:
# Result =  5

# %%
a = 12
b = 5

print("AND  :", a & b)
print("OR   :", a | b)
print("XOR  :", a ^ b)
print("NOT  :", ~a)
print("Left :", a << 1)
print("Right:", a >> 1)
# Out:
# AND  : 4
# OR   : 13
# XOR  : 9
# NOT  : -13
# Left : 24
# Right: 6

# %%
fruits = ["apple", "banana", "mango", "orange"]

is_present = "mango" in fruits

# %%
fruits = ["apple", "banana", "mango", "orange"]

result = "grapes" not in fruits

# %%
name = "Python Programming"

python_check = "Python" in name
java_check = "Java" not in name

# %%
a = [1, 2, 3]
b = a

same_object = a is b

# %%
a = [1, 2, 3]
b = [1, 2, 3]

different_objects = a is not b
#a and b are different objects

# %%
a = 20
b = 10

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Floor Division:", a // b)
print("Exponent:", a ** b)
print("Greater than:", a > b)
print("Equal to:", a == b)
# Out:
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0
# Modulus: 0
# Floor Division: 2
# Exponent: 10240000000000
# Greater than: True
# Equal to: False

# %%
a = 15
b = 4

print("15 + 4 =", a + b)
print("15 - 4 =", a - b)
print("15 * 4 =", a * b)
print("15 / 4 =", a / b)
print("15 % 4 =", a % b)
print("15 // 4 =", a // b)
print("15 ** 4 =", a ** b)
# Out:
# 15 + 4 = 19
# 15 - 4 = 11
# 15 * 4 = 60
# 15 / 4 = 3.75
# 15 % 4 = 3
# 15 // 4 = 3
# 15 ** 4 = 50625

# %%
maths = 80
python = 90
english = 75

total = maths + python + english
average = total / 3
total_check = total > 200
python_check = python == 90

print("Total marks =", total)
print("Average marks =", average)
print("Total greater than 200 =", total_check)
print("Python marks equal to 90 =", python_check)
# Out:
# Total marks = 245
# Average marks = 81.66666666666667
# Total greater than 200 = True
# Python marks equal to 90 = True

# %%
price = 250
quantity = 4

total_amount = price * quantity
print("Total amount =", total_amount)

amount_check = total_amount > 500
print("Is the total above 500 =", amount_check)
# Out:
# Total amount = 1000
# Is the total above 500 = True

# %%
students = 53
group_size = 6

complete_groups = students // group_size
print("Complete groups =", complete_groups)

remaining_students = students % group_size
print("Students left =", remaining_students)
# Out:
# Complete groups = 8
# Students left = 5
