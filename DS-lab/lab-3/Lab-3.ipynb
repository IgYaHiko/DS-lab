# %%
student = (101, "Palika", 9.1)

print(student)
# Out:
# (101, 'Palika', 9.1)

# %%
numbers = tuple(map(int, input("Enter 6 integers: ").split()))

print("Original tuple:", numbers)
print("Reversed tuple:", numbers[::-1])
# Out:
# Enter 6 integers: 1 2 3 4 5 6
# Original tuple: (1, 2, 3, 4, 5, 6)
# Reversed tuple: (6, 5, 4, 3, 2, 1)

# %%
t = (10, 20, 30, 40, 50, 60)

print(t[1:-1])
# Out:
# (20, 30, 40, 50)

# %%
first = (1, 2, 3)
second = (4, 5)

combined = first + second

print("Joined tuple:", combined)
# Out:
# Joined tuple: (1, 2, 3, 4, 5)

# %%
numbers = (1, 3, 5)

result = numbers * 3

print(result)
# Out:
# (1, 3, 5, 1, 3, 5, 1, 3, 5)

# %%
numbers = (10, 15, 20, 25, 30)

value = int(input("Enter a number to search: "))

print(value in numbers)
# Out:
# Enter a number to search: 3
# False

# %%
numbers = (1, 2, 3, 2, 4, 2)

value = int(input("Enter the value to count: "))

print("Occurrences:", numbers.count(value))
# Out:
# Enter the value to count: 2
# Occurrences: 3

# %%
numbers = (5, 10, 15, 20)

value = int(input("Enter the value to find: "))

print("Index:", numbers.index(value))
# Out:
# Enter the value to find: 10
# Index: 1

# %%
numbers = tuple(map(int, input("Enter numbers: ").split()))

print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
# Out:
# Enter numbers: 1 2 3 4 5
# Maximum: 5
# Minimum: 1

# %%
numbers = tuple(map(int, input("Enter numbers: ").split()))

print("Sum:", sum(numbers))
# Out:
# Enter numbers: 1 2 3 4 5
# Sum: 15

# %%
text = input("Enter a string: ")

characters = tuple(text)

print("Tuple:", characters)

for ch in characters:
    print(ch)
# Out:
# Enter a string: abcd
# Tuple: ('a', 'b', 'c', 'd')
# a
# b
# c
# d

# %%
items = [11, 22, 33, 44]

result = tuple(items)

print(result)
print(type(result))
# Out:
# (11, 22, 33, 44)
# <class 'tuple'>

# %%
numbers = tuple(map(int, input("Enter numbers: ").split()))

sorted_numbers = sorted(numbers)

print("Sorted tuple:", sorted_numbers)
# Out:
# Enter numbers: 3 4 2 3 1 5
# Sorted tuple: [1, 2, 3, 3, 4, 5]

# %%
numbers = tuple(map(int, input("Enter numbers: ").split()))

print("Length of tuple:", len(numbers))
# Out:
# Enter numbers: 1 2 3 4
# Length of tuple: 4

# %%
numbers = (2, 4, 6, 8, 10)

result = all(number % 2 == 0 for number in numbers)

print(result)
# Out:
# True

# %%
marks = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69,
    "Neha": 90,
    "Arjun": 74
}

print("Students:")
for name in marks.keys():
    print(name)

print("\nMarks:")
for score in marks.values():
    print(score)
# Out:
# Students:
# Aman
# Riya
# Kabir
# Neha
# Arjun
#
# Marks:
# 78
# 85
# 69
# 90
# 74

# %%
marks = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69,
    "Neha": 90,
    "Arjun": 74
}

name = input("Enter student name: ")

if name in marks:
    print("Key found. Value =", marks[name])
else:
    print("Key not found.")
# Out:
# Enter student name: rishi
# Key not found.

# %%
d1 = {1: "A", 2: "B"}
d2 = {3: "C", 4: "D"}

merged = d1.copy()
merged.update(d2)

print("Merged dictionary:", merged)
# Out:
# Merged dictionary: {1: 'A', 2: 'B', 3: 'C', 4: 'D'}

# %%
prices = {
    "Apple": 100,
    "Banana": 40,
    "Mango": 60
}

fruit = input("Enter fruit name: ")
new_price = int(input("Enter new price: "))

if fruit in prices:
    prices[fruit] = new_price
    print("Updated dictionary:", prices)
else:
    print("Fruit not found.")
# Out:
# Enter fruit name: Apple
# Enter new price: 120
# Updated dictionary: {'Apple': 120, 'Banana': 40, 'Mango': 60}

# %%
prices = {
    "Apple": 120,
    "Banana": 40,
    "Mango": 60
}

fruit = input("Enter fruit to delete: ")

if fruit in prices:
    del prices[fruit]
    print("Updated dictionary:", prices)
else:
    print("Fruit not found.")
# Out:
# Enter fruit to delete: Apple
# Updated dictionary: {'Banana': 40, 'Mango': 60}

# %%
students = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69
}

print("Number of keys:", len(students))
# Out:
# Number of keys: 3

# %%
students = {
    101: "Amit",
    102: "Neha",
    103: "Rahul"
}

for student_id, name in students.items():
    print(student_id, "->", name)
# Out:
# 101 -> Amit
# 102 -> Neha
# 103 -> Rahul

# %%
marks = {
    "English": 82,
    "Maths": 95,
    "Science": 88,
    "Computer": 91
}

top_subject = max(marks, key=marks.get)

print("Highest marks:", top_subject, "=", marks[top_subject])
# Out:
# Highest marks: Maths = 95

# %%
keys = [1, 2, 3]
values = ["A", "B", "C"]

result = dict(zip(keys, values))

print(result)
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %%
original = {
    1: 10,
    2: 20
}

copied = original.copy()

print("Original dictionary:", original)
print("Copied dictionary:", copied)
# Out:
# Original dictionary: {1: 10, 2: 20}
# Copied dictionary: {1: 10, 2: 20}

# %%
marks = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 90,
    "Neha": 72
}

value = int(input("Enter a value to search: "))

if value in marks.values():
    print("Value exists")
else:
    print("Value does not exist")
# Out:
# Enter a value to search: 85
# Value exists

# %%
items = {
    1: 10,
    2: 20,
    3: 30
}

removed = items.popitem()

print("Removed:", removed)
print("Updated dictionary:", items)
# Out:
# Removed: (3, 30)
# Updated dictionary: {1: 10, 2: 20}

# %%
items = {
    "Pen": 10,
    "Pencil": 20
}

item = input("Enter item: ")

if item in items:
    items[item] += 5
    print("Updated dictionary:", items)
else:
    print("Item not found.")
# Out:
# Enter item: Pen
# Updated dictionary: {'Pen': 15, 'Pencil': 20}

# %%
items = {
    "Pen": 15,
    "Pencil": 20
}

for item, quantity in items.items():
    print(item, ":", quantity)
# Out:
# Pen : 15
# Pencil : 20

# %%
student_marks = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69
}

student_marks.clear()

print(student_marks)
# Out:
# {}

# %%
squares = {}

for number in range(1, 6):
    squares[number] = number ** 2

print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
ages = {
    "Aman": 20,
    "Riya": 22,
    "Neha": 21,
    "Arjun": 23
}

name = input("Enter name: ")

if name in ages:
    print("Age:", ages[name])
else:
    print("Name not found.")
# Out:
# Enter name: Aman
# Age: 20

# %%
data = {}

for i in range(3):
    key = input("Enter key: ")
    value = input("Enter value: ")
    data[key] = value

print("Dictionary:", data)
# Out:
# Enter key: Aman
# Enter value: 10
# Enter key: Rishi
# Enter value: 20
# Enter key: Rohan
# Enter value: 22
# Dictionary: {'Aman': '10', 'Rishi': '20', 'Rohan': '22'}

# %%
countries = {
    "India": "Delhi",
    "Japan": "Tokyo",
    "France": "Paris"
}

print("Capitals:")

for capital in countries.values():
    print(capital)
# Out:
# Capitals:
# Delhi
# Tokyo
# Paris

# %%
marks = {
    "Aman": 45,
    "Riya": 75,
    "Kabir": 60,
    "Neha": 40
}

count = 0

for mark in marks.values():
    if mark > 50:
        count += 1

print("Values greater than 50:", count)
# Out:
# Values greater than 50: 2

# %%
numbers = input("Enter numbers: ").split()

unique_numbers = set(numbers)

print("Set:", unique_numbers)
# Out:
# Enter numbers: 1 2 3 4 5
# Set: {'2', '5', '3', '1', '4'}

# %%
my_set = {10, 5.5, "Python"}

print("Set:", my_set)
print("Length:", len(my_set))
# Out:
# Set: {'Python', 10, 5.5}
# Length: 3

# %%
cities = ["Delhi", "Mumbai", "Delhi", "Chandigarh", "Mumbai", "Pune"]

unique_cities = set(cities)

print("Unique cities:", unique_cities)
# Out:
# Unique cities: {'Delhi', 'Pune', 'Mumbai', 'Chandigarh'}

# %%
my_set = set()

for i in range(3):
    value = input("Enter element: ")
    my_set.add(value)

print("Updated set:", my_set)
# Out:
# Enter element: 10
# Enter element: 20
# Enter element: 22
# Updated set: {'10', '22', '20'}

# %%
numbers = {2, 4, 6}

new_number = int(input("Enter a number to add: "))

numbers.add(new_number)

print("Updated set:", numbers)
# Out:
# Enter a number to add: 11
# Updated set: {2, 11, 4, 6}

# %%
numbers = {1, 2, 3}
values = (4, 5, 6)

numbers.update(values)

print("Updated set:", numbers)
# Out:
# Updated set: {1, 2, 3, 4, 5, 6}

# %%
letters = {"a", "b"}

text = input("Enter a string: ")

letters.update(text)

print("Updated set:", letters)
# Out:
# Enter a string: abcd
# Updated set: {'c', 'b', 'a', 'd'}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}

set_a.update(set_b)

print("Merged set:", set_a)
# Out:
# Merged set: {1, 2, 3, 4, 5}

# %%
numbers = {2, 4, 6, 8, 10}

value = int(input("Enter element to delete: "))

numbers.discard(value)

print("Updated set:", numbers)
# Out:
# Enter element to delete: 4
# Updated set: {2, 6, 8, 10}

# %%
numbers = {3, 7, 10, 12, 5, 15, 18, 8}

numbers = {number for number in numbers if number >= 10}

print("Updated set:", numbers)
# Out:
# Updated set: {10, 18, 12, 15}

# %%
languages = {"Python", "Java", "C", "C++", "JavaScript"}

language = input("Enter a programming language: ")

if language in languages:
    print("Language exists in the set.")
else:
    print("Language does not exist in the set.")
# Out:
# Enter a programming language: Java
# Language exists in the set.

# %%
numbers = {3, 5, 6, 8, 9, 10, 12, 14, 15}

numbers = {number for number in numbers if number % 3 != 0}

print("Final set:", numbers)
# Out:
# Final set: {8, 10, 5, 14}

# %%
set_a = {1, 2, 3, 4, 5}
set_b = {4, 5, 6, 7, 8}

print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
print("Symmetric Difference:", set_a ^ set_b)
# Out:
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}
# Difference (A - B): {1, 2, 3}
# Symmetric Difference: {1, 2, 3, 6, 7, 8}

# %%
math_students = {"Aman", "Riya", "Kabir", "Neha"}
physics_students = {"Riya", "Kabir", "Arjun", "Simran"}

both_courses = math_students & physics_students

print("Students enrolled in both:", both_courses)
# Out:
# Students enrolled in both: {'Kabir', 'Riya'}

# %%
course_a = {101, 102, 103, 104}
course_b = {103, 104, 105, 106}

only_one = course_a ^ course_b

print("Students enrolled in exactly one course:", only_one)
# Out:
# Students enrolled in exactly one course: {101, 102, 105, 106}

# %%
set_a = {1, 2, 3}
set_b = {4, 5, 6}

if set_a.isdisjoint(set_b):
    print("The sets have no common elements.")
else:
    print("The sets have common elements.")
# Out:
# The sets have no common elements.

# %%
set_a = {1, 2, 3}
set_b = {1, 2, 3, 4, 5}

print("A is subset of B:", set_a.issubset(set_b))
print("A is superset of B:", set_a.issuperset(set_b))
# Out:
# A is subset of B: True
# A is superset of B: False

# %%
sentence = input("Enter a sentence: ")

unique_chars = set(sentence.replace(" ", ""))

print("Unique characters:", unique_chars)
# Out:
# Enter a sentence: abcd
# Unique characters: {'c', 'b', 'a', 'd'}
